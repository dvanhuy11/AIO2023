# %%
#@title Code 
def generate(list,k):
  nlist = list * k
  # nlist = sorted(nlist)
  return nlist

data = [1,2,3]
k=2

data1 = [4,5,]
k1 = 3

print(generate(data,k))
print(generate(data1,k1))
# Out:
# [1, 2, 3, 1, 2, 3]
# [4, 5, 4, 5, 4, 5]
